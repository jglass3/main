# %% [markdown]
# # ASSOCIATION ANALYSIS WITH FP-GROWTH
#
# **File:** FPGrowth.ipynb
#
# **Course:** Data Science Foundations: Data Mining in Python

# %% [markdown]
# # INSTALL AND IMPORT PACKAGES
# The Python package `mlxtend` contains the implementation of the FP-growth algorithm, which can be installed with Python's `pip` command. This command only needs to be done once per machine.
#
# The standard, shorter approach may work:

# %%
#Creates frequent pattern trees
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\t8367j1\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (1.3.4)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.20.3 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (0.24.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: setuptools in c:\users\t8367j1\anaconda3\lib\site-packages (from mlxtend) (58.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\t8367j1\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\t8367j1\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\t8367j1\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\t8367j1\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\t8367j1\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied: six in c:\users\t8367j1\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\t8367j1\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\t8367j1\anaconda3\lib\site-packages (from scikit-learn>=0.20.3->mlxtend) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# If the above command didn't work, it may be necessary to be more explicit, in which case you could run the code below.

# %%
# import sys
# !{sys.executable} -m pip install mlxtend

# %% [markdown]
# Once `mlxtend` is installed, then load the packages below.

# %%
import pandas as pd                                   # For dataframes
import matplotlib.pyplot as plt                       # For plotting data
from mlxtend.preprocessing import TransactionEncoder  # For FP-tree algorithm
from mlxtend.frequent_patterns import fpgrowth        # For FP-tree algorithm

# %% [markdown]
# # LOAD AND PREPARE DATA
# For this demonstration, we'll use the dataset `Groceries.csv`, which comes from the R package `arules` and is saved as a CSV file. The data is in transactional format (as opposed to tabular format), which means that each row is a list of items purchased together and that the items may be in different order. There are 32 columns in each row, each column either contains a purchased items or NaN.

# %% [markdown]
# ## Import Data
#
# - To read read the dataset from a local CSV file, run the following cell.

# %%
transactions = []

with open('Groceries.csv') as f:
    for line in f:
        transaction = [item for item in line.strip().split(',') if item != 'NaN']
        transactions.append(transaction)
    
transactions[:3]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk']]

# %% [markdown]
# # APPLY FP-GROWTH
#
# ## Prepare Data
#
# - Create a "wide" dataframe where each column corresponds to a single good.

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

df.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# 1           False      False  False          False             False  False
# 2           False      False  False          False             False  False
# 3           False      False  False          False             False  False
# 4           False      False  False          False             False  False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False        True   False     False
# 3       False       False    True     False
# 4       False        True   False     False
#
# [5 rows x 169 columns]

# %% [markdown]
# ## Build Rules
#
# - Call `fpgrowth()` on `transactions`.
# - As parameters `fpgrowth()` can take the minimum support ratio and minimum confidence.
# - Only the pairs of items that satisfy these criteria would be returned.

# %%
rules_df = fpgrowth(df, min_support=0.01, use_colnames=True, max_len=2, verbose=False)

rules_df = rules_df[rules_df.itemsets.map(len) == 2]
rules_df['From'] = rules_df['itemsets'].map(lambda x: list(x)[0])
rules_df['To'] = rules_df['itemsets'].map(lambda x: list(x)[1])
rules_df['N'] = (rules_df['support'] * len(transactions)).astype(int)

rules_df.sort_values('N', ascending=False, inplace=True)

rules_df.head()
# Out:
#       support                             itemsets             From  \
# 132  0.074835       (whole milk, other vegetables)       whole milk
# 142  0.056634             (rolls/buns, whole milk)       rolls/buns
# 104  0.056024                 (whole milk, yogurt)       whole milk
# 219  0.048907        (root vegetables, whole milk)  root vegetables
# 217  0.047382  (root vegetables, other vegetables)  root vegetables
#
#                    To    N
# 132  other vegetables  736
# 142        whole milk  557
# 104            yogurt  551
# 219        whole milk  481
# 217  other vegetables  466

# %% [markdown]
# ## List Rules with N's
# - The code below calls `plot()` on each row of the rules DataFrame to create a list of all the mined rules.
# - First, we have to add two numeric columns corresponding to each item to `rules_df`.

# %%
# Pick top rules
rules_df = rules_df.sort_values('N', ascending=False).head(50)

# List of all items
items = set(rules_df['From']) | set(rules_df['To'])

# Creates a mapping of items to numbers
imap = {item : i for i, item in enumerate(items)}

# Maps the items to numbers and adds the numeric 'FromN' and 'ToN' columns
rules_df['FromN'] = rules_df['From'].map(imap)
rules_df['ToN'] = rules_df['To'].map(imap)

# Displays the top 20 association rules, sorted by Support
rules_df.head(20)
# Out:
#       support                             itemsets              From  \
# 132  0.074835       (whole milk, other vegetables)        whole milk
# 142  0.056634             (rolls/buns, whole milk)        rolls/buns
# 104  0.056024                 (whole milk, yogurt)        whole milk
# 219  0.048907        (root vegetables, whole milk)   root vegetables
# 217  0.047382  (root vegetables, other vegetables)   root vegetables
# 107  0.043416           (yogurt, other vegetables)            yogurt
# 141  0.042603       (rolls/buns, other vegetables)        rolls/buns
# 111  0.042298         (whole milk, tropical fruit)        whole milk
# 173  0.040061                   (whole milk, soda)        whole milk
# 172  0.038332                   (rolls/buns, soda)        rolls/buns
# 109  0.035892   (other vegetables, tropical fruit)  other vegetables
# 106  0.034367                 (rolls/buns, yogurt)        rolls/buns
# 149  0.034367          (whole milk, bottled water)        whole milk
# 207  0.033249                 (whole milk, pastry)        whole milk
# 174  0.032740             (soda, other vegetables)              soda
# 264  0.032232     (whole milk, whipped/sour cream)        whole milk
# 230  0.030605                (rolls/buns, sausage)        rolls/buns
# 88   0.030503           (whole milk, citrus fruit)        whole milk
# 119  0.030097              (whole milk, pip fruit)        whole milk
# 282  0.029995          (whole milk, domestic eggs)        whole milk
#
#                      To    N  FromN  ToN
# 132    other vegetables  736     19   22
# 142          whole milk  557      2   19
# 104              yogurt  551     19   10
# 219          whole milk  481      3   19
# 217    other vegetables  466      3   22
# 107    other vegetables  427     10   22
# 141    other vegetables  419      2   22
# 111      tropical fruit  416     19   18
# 173                soda  394     19   13
# 172                soda  377      2   13
# 109      tropical fruit  353     22   18
# 106              yogurt  337      2   10
# 149       bottled water  337     19    8
# 207              pastry  327     19    0
# 174    other vegetables  322     13   22
# 264  whipped/sour cream  317     19   21
# 230             sausage  301      2    9
# 88         citrus fruit  300     19   15
# 119           pip fruit  296     19    4
# 282       domestic eggs  295     19    1

# %% [markdown]
# ## Plot Rules
# Plot each pair of items in the rule. If a rule is A->B, then the item A is in the bottom row of the plot (y=0) and B is in the top row (y=1). The color of each line indicates the support of the rule multiplied by 10 (support*10).

# %%
# Adds ticks to the top of the graph also
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True

# Sets the size of the plot
fig = plt.figure(figsize=(15, 7))

# Draws a line between items for each rule
# Colors each line according to the support of the rule
for index, row in rules_df.head(20).iterrows():
    plt.plot([row['FromN'], row['ToN']], [0, 1], 'o-',
             c=plt.cm.viridis(row['support'] * 10),
             markersize=20)

# Adds a colorbar and its title  
cb = plt.colorbar(plt.cm.ScalarMappable(cmap='viridis'))
cb.set_label('Support*10')

# Adds labels to xticks and removes yticks
plt.xticks(range(len(items)), items, rotation='vertical')
plt.yticks([])
plt.show()
