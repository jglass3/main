# %% [markdown]
# # t-SNE: t-DISTRIBUTED STOCHASTIC NEIGHBOR EMBEDDING
#
# **File:** tSNE.ipynb
#
# **Course:** Data Science Foundations: Data Mining in Python

# %% [markdown]
# # IMPORT LIBRARIES

# %%
#Method used for visualing high demensional data, not for classification, so no train/testing
import pandas as pd                # For dataframe
import matplotlib.pyplot as plt    # For plotting data
import seaborn as sns              # For plotting data
from sklearn.manifold import TSNE  # For tSNE

# %% [markdown]
# # LOAD AND PREPARE DATA
#
# Load the complete dataset (as opposed to the training or testing data) from the CSV file in the data directory. Separate the data matrix from the class variable. Name the data matrix as `df` and the column with class labels as `y`.

# %%
# Imports the complete dataset
df = pd.read_csv('optdigits.csv')

# Separates the attributes P0-P63 into X
X = df.filter(regex='\d')

# Separates the class variable into y
y = df.y

# %%
# Shows the first few rows of the data
df.head()
#P values tell how many pixels are actived within a given region, y = number
# Out:
#    P0  P1  P2  P3  P4  P5  P6  P7  P8  P9  ...  P55  P56  P57  P58  P59  P60  \
# 0   0   0   5  14   4   0   0   0   0   0  ...    0    0    0    4   12   14
# 1   0   0   0   3  16  11   1   0   0   0  ...    0    0    0    0    2   14
# 2   0   0   7  11  11   6   0   0   0   9  ...    0    0    0   14   16   12
# 3   0   0   9  13   1   0   0   0   0   0  ...    5    0    0    4   15   16
# 4   0   0   0  10  12   0   0   0   0   0  ...    0    0    0    1   11   14
#
#    P61  P62  P63  y
# 0    7    0    0  6
# 1   14    1    0  1
# 2   10    1    0  3
# 3   16   16   16  1
# 4   12    1    0  6
#
# [5 rows x 65 columns]

# %% [markdown]
# # t-SNE: MODEL DATA
#
# This phase applies t-SNE to the training data with various values of the perplexity parameter and displays embeddings of data.

# %%
# Sets up the t-SNE object with 2 components
#Have to specific number of components
tsne = TSNE(
    n_components=2,
    random_state=1)

# %%
# Displays the t-SNE parameters
tsne.get_params()
# Out:
# {'angle': 0.5,
#  'early_exaggeration': 12.0,
#  'init': 'random',
#  'learning_rate': 200.0,
#  'method': 'barnes_hut',
#  'metric': 'euclidean',
#  'min_grad_norm': 1e-07,
#  'n_components': 2,
#  'n_iter': 1000,
#  'n_iter_without_progress': 300,
#  'n_jobs': None,
#  'perplexity': 30.0,
#  'random_state': 1,
#  'square_distances': 'legacy',
#  'verbose': 0}

# %% [markdown]
# ## PERPLEXITY = 1

# %%
# Sets up t-SNE with perplexity (parameter) = 1
#perplexity - how it combines high dimensionality data down into our 2 dimensional system
#Starting perplexity with 1, which you don't ever want to do
tsne = TSNE(
    n_components=2,
    perplexity=1,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
#Doesn't help us out
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PERPLEXITY = 2

# %%
# Sets up t-SNE with perplexity = 2
tsne = TSNE(
    n_components=2,
    perplexity=2,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PERPLEXITY = 5

# %%
# Sets up t-SNE with perplexity = 5
tsne = TSNE(
    n_components=2,
    perplexity=5,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
#clean seperation, however one blue in green, looked at that data point and number
#was very smudged
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PERPLEXITY = 10

# %%
# Sets up t-SNE with perplexity = 10
tsne = TSNE(
    n_components=2,
    perplexity=10,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
#perplexity within 10-20 range most help, probably
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PERPLEXITY = 50

# %%
# Sets up t-SNE with perplexity = 50
tsne = TSNE(
    n_components=2,
    perplexity=50,
    random_state=1)

# Transforms the attribute data
X_tf = tsne.fit_transform(X)

# Creates a scatterplot of the data embedding
sns.scatterplot(
    x=X_tf[:, 0],
    y=X_tf[:, 1],
    style=y,
    hue=y,
    palette=['red', 'green', 'blue'])
# Out:
# <AxesSubplot:>
